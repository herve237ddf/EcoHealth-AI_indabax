# %%
import pandas as pd
def load_data(file_path):
    df = pd.read_csv(file_path)
    return df

# %%
df = load_data("climat_air_quality.csv")    
df.head(10)
# Out:
#    temperature_2m_max  temperature_2m_min  temperature_2m_mean  \
# 0                31.4                16.2                 22.9
# 1                30.2                16.0                 22.4
# 2                30.3                16.6                 22.7
# 3                30.9                15.9                 22.5
# 4                31.6                15.6                 22.8
# 5                30.9                18.5                 23.4
# 6                32.3                17.5                 24.1
# 7                32.3                17.3                 24.1
# 8                32.0                19.3                 24.6
# 9                29.4                20.0                 23.7
#
#    apparent_temperature_max  apparent_temperature_min  \
# 0                      33.6                      15.7
# 1                      31.2                      15.0
# 2                      30.2                      15.1
# ...

# %%
df.columns
# Out:
# Index(['temperature_2m_max', 'temperature_2m_min', 'temperature_2m_mean',
#        'apparent_temperature_max', 'apparent_temperature_min',
#        'apparent_temperature_mean', 'daylight_duration', 'sunshine_duration',
#        'precipitation_sum', 'rain_sum', 'precipitation_hours',
#        'wind_speed_10m_max', 'wind_gusts_10m_max',
#        'wind_direction_10m_dominant', 'shortwave_radiation_sum',
#        'et0_fao_evapotranspiration', 'city', 'region', 'latitude', 'longitude',
#        'mois', 'annee', 'amplitude_thermique', 'ecart_ressenti',
#        'bilan_hydrique', 'quarter', 'day_of_year', 'month_sin', 'month_cos',
#        'day_sin', 'day_cos', 'is_dry_season', 'is_weekend', 'sunshine_ratio',
#        'is_no_wind', 'is_no_rain', 'gust_ratio', 'heat_stress', 'is_hot_day',
#        'is_heavy_rain', 'temp_per_radiation', 'temp_lag1', 'wind_lag1',
#        'precip_lag1', 'wind_dir_lag1', 'sunshine_lag1', 'temp_lag3',
# ...

# %%
#conception des filtres pour les données
# df['annee'] = df['time'].dt.year
# df['mois_nom'] = df['time'].dt.month_name().str[:4]

annee = df["annee"].unique()
mois = {1: "Janvier", 2: "Février", 3: "Mars", 4: "Avril", 5: "Mai", 6: "Juin", 7: "Juillet", 8: "Août", 9: "Septembre", 10: "Octobre", 11: "Novembre", 12: "Décembre"}
regions = df["region"].unique()
citys = df["city"].unique()
